# %%
#현재 경로 확인
import os
print(os.getcwd())
# Out:
# /content

# %%
#경로 변경
os.chdir('/content/sample_data/')

# %%
#파일불러오기(na_values 설정)
#공백이나 Missing표기 등을 모두 NaN이라는 표시로 변경
import pandas as pd
df = pd.read_excel('tox21_ac50.xlsx', na_values=['','  ', ' ','NA', 'N/A', 'Missing'])
print(df)
# Out:
#                                  PREFERRED NAME       CASRN  \
# 0                                  Aroclor 1260  11096-82-5
# 1                 4-Biphenylamine hydrochloride   2113-61-3
# 2                         Benzyl isothiocyanate    622-78-6
# 3     2-Chloro-1,4-diaminobenzene sulfate (1:1)  61702-44-1
# 4                                      Caffeine     58-08-2
# ...                                         ...         ...
# 1454                 Thioridazine hydrochloride    130-61-0
# 1455                                Nitromersol    133-58-4
# 1456                                   BisOPP-A  24038-68-4
# 1457                       Dienestrol diacetate     84-19-5
# 1458                                Amidoflumet  84466-05-7
#
#                                                  SMILES       AC50
# 0                                                   NaN  15.145586
# 1                          Cl.NC1=CC=C(C=C1)C1=CC=CC=C1  18.505932
# ...

# %%
# 데이터 프레임 출력
df
# Out:
#                                  PREFERRED NAME       CASRN  \
# 0                                  Aroclor 1260  11096-82-5
# 1                 4-Biphenylamine hydrochloride   2113-61-3
# 2                         Benzyl isothiocyanate    622-78-6
# 3     2-Chloro-1,4-diaminobenzene sulfate (1:1)  61702-44-1
# 4                                      Caffeine     58-08-2
# ...                                         ...         ...
# 1454                 Thioridazine hydrochloride    130-61-0
# 1455                                Nitromersol    133-58-4
# 1456                                   BisOPP-A  24038-68-4
# 1457                       Dienestrol diacetate     84-19-5
# 1458                                Amidoflumet  84466-05-7
#
#                                                  SMILES       AC50
# 0                                                   NaN  15.145586
# 1                          Cl.NC1=CC=C(C=C1)C1=CC=CC=C1  18.505932
# ...

# %%
# 데이터프레임 칼럼명 출력
df.columns
# Out:
# Index(['PREFERRED NAME', 'CASRN', 'SMILES', 'AC50'], dtype='object')

# %%
# 데이터 프레임 정보 출력(칼럼명, null값, Dtype확인 가능)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PREFERRED NAME  1459 non-null   object
#  1   CASRN           1459 non-null   object
#  2   SMILES          1426 non-null   object
#  3   AC50            1459 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 45.7+ KB

# %%
# 데이터 프레임 처음부터 5개의 행 출력
df.head()
# Out:
#                               PREFERRED NAME       CASRN  \
# 0                               Aroclor 1260  11096-82-5
# 1              4-Biphenylamine hydrochloride   2113-61-3
# 2                      Benzyl isothiocyanate    622-78-6
# 3  2-Chloro-1,4-diaminobenzene sulfate (1:1)  61702-44-1
# 4                                   Caffeine     58-08-2
#
#                             SMILES       AC50
# 0                              NaN  15.145586
# 1     Cl.NC1=CC=C(C=C1)C1=CC=CC=C1  18.505932
# 2                S=C=NCC1=CC=CC=C1  45.000000
# 3  OS(O)(=O)=O.NC1=CC=C(N)C(Cl)=C1  41.224635
# 4     CN1C=NC2=C1C(=O)N(C)C(=O)N2C  38.479043

# %%
#데이터 프레임 처음부터 10개의 행 출력
df.head(10)
# Out:
#                               PREFERRED NAME       CASRN  \
# 0                               Aroclor 1260  11096-82-5
# 1              4-Biphenylamine hydrochloride   2113-61-3
# 2                      Benzyl isothiocyanate    622-78-6
# 3  2-Chloro-1,4-diaminobenzene sulfate (1:1)  61702-44-1
# 4                                   Caffeine     58-08-2
# 5                             Chlorothalonil   1897-45-6
# 6                              Cyclosporin A  59865-13-3
# 7                                     Diuron    330-54-1
# 8                          2,4-Dinitrophenol     51-28-5
# 9                                  Mestranol     72-33-3
#
#                                               SMILES       AC50
# 0                                                NaN  15.145586
# 1                       Cl.NC1=CC=C(C=C1)C1=CC=CC=C1  18.505932
# 2                                  S=C=NCC1=CC=CC=C1  45.000000
# 3                    OS(O)(=O)=O.NC1=CC=C(N)C(Cl)=C1  41.224635
# ...

# %%
#데이터 프레임 끝에서 부터 10개의 행 출력
df.tail(10)
# Out:
#                                          PREFERRED NAME        CASRN  \
# 1449                               3-Acetylphenanthrene    2039-76-1
# 1450  1-Methyl-3-tetradecylimidazolium bis(trifluoro...  404001-49-6
# 1451            (±)-cis-3-Methyl fentanyl hydrochloride   78995-18-3
# 1452  1-Dodecyl-3-methylimidazolium trifluoromethane...  404001-52-1
# 1453        (±)-cis-3-Methyl thiofentanyl hydrochloride  131690-45-4
# 1454                         Thioridazine hydrochloride     130-61-0
# 1455                                        Nitromersol     133-58-4
# 1456                                           BisOPP-A   24038-68-4
# 1457                               Dienestrol diacetate      84-19-5
# 1458                                        Amidoflumet   84466-05-7
#
#                                                  SMILES       AC50
# 1449                CC(=O)C1=CC2=C(C=C1)C=CC1=CC=CC=C21   9.970949
# 1450  FC(F)(F)S(=O)(=O)[N-]S(=O)(=O)C(F)(F)F.CCCCCCC...   1.194256
# ...

# %%
#null값 개수 출력
missing_values_count = df.isna().sum()
print(missing_values_count)
# Out:
# PREFERRED NAME     0
# CASRN              0
# SMILES            33
# AC50               0
# dtype: int64

# %%
#SMILES null값 제거
df = df.dropna(subset=['SMILES'])

# %%
#null값 행 출력
df[df.isnull().any(1)]
# Out:
# <ipython-input-20-d169372ee7ff>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df[df.isnull().any(1)]
# Empty DataFrame
# Columns: [PREFERRED NAME, CASRN, SMILES, AC50]
# Index: []

# %%
#Null 값 존재하는지 재확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1426 entries, 1 to 1458
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PREFERRED NAME  1426 non-null   object
#  1   CASRN           1426 non-null   object
#  2   SMILES          1426 non-null   object
#  3   AC50            1426 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 55.7+ KB

# %%
df['AC50'].mean()  #평균
# Out:
# 27.21919221657311

# %%
df['AC50'].var()   #분산
# Out:
# 451.16129420187355

# %%
df['AC50'].std()   #표준편차
# Out:
# 21.240557765790275

# %%
df['AC50'].min()   #최소값
# Out:
# 1.1780973994419705e-05

# %%
df['AC50'].max()   #최대값
# Out:
# 95.78188479534123

# %%
df['AC50'].median()  #중앙값
# Out:
# 22.816547945883872

# %%
df['AC50'].quantile(0.25)    #분위수
# Out:
# 9.255088296837618

# %%
df['AC50'].quantile(q=[0.25, 0.5, 0.75])
# Out:
# 0.25     9.255088
# 0.50    22.816548
# 0.75    41.230782
# Name: AC50, dtype: float64

# %%
df['AC50'].describe()
# Out:
# count    1426.000000
# mean       27.219192
# std        21.240558
# min         0.000012
# 25%         9.255088
# 50%        22.816548
# 75%        41.230782
# max        95.781885
# Name: AC50, dtype: float64

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df['AC50'].plot(title='default-line', figsize=(20,3))
# Out:
# <Axes: title={'center': 'default-line'}>

# %%
df['AC50'].plot(title='histogram',
                     kind='hist',
                     figsize=(3,3))
# Out:
# <Axes: title={'center': 'histogram'}, ylabel='Frequency'>

# %%
df['AC50'].plot(title='boxplot',
                     kind='box',
                     figsize=(3,3))
# Out:
# <Axes: title={'center': 'boxplot'}>

# %%
import matplotlib.pyplot as plt


plt.subplot(1,2,1)
plt.plot(df['AC50'],'o', ms=3)
plt.subplot(1,2,2)
plt.plot(df['AC50'],'^',color='red',ms=3)

plt.tight_layout()

# %%
# !pip install stemgraphic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 1.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=6f773c52b57ca3230d571debe24b3bec8353426636a97a65a8cf4e93b255e346
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# ...

# %%
import stemgraphic

stemgraphic.stem_graphic(df.AC50)
# Out:
# (<Figure size 750x525 with 1 Axes>, <Axes: >)

# %%
df.AC50.plot(kind='box',title='Boxplot',ylabel='AC50',figsize=(3,3))
plt.xticks([])
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.boxplot(df.AC50)
plt.ylabel('AC50')
plt.title('BoxPlot')
plt.xticks([])
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.boxplot(df.AC50)
plt.ylabel('AC50')
plt.title('BoxPlot')
plt.xticks([])
plt.show()

# %%
plt.subplot(1,2,1)
sns.histplot(data=df, x='AC50')
plt.title('(1)')

plt.subplot(1,2,2)
sns.histplot(data=df, x='AC50', bins=50)
plt.title('(2)')


plt.tight_layout()
plt.show()
